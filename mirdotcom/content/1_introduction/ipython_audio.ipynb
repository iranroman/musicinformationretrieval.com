# %% [markdown]
# # Jupyter Audio Basics

# %%
from mirdotcom import mirdotcom

mirdotcom.init()

# %% [markdown]
# ## Audio Libraries

# %% [markdown]
# We will mainly use two libraries for audio acquisition and playback:

# %% [markdown]
# ### 1. librosa
#
# [`librosa`](https://librosa.org/doc/latest/index.html) is a Python package for music and audio processing by [Brian McFee](https://brianmcfee.net/). A large portion was ported from [Dan Ellis's Matlab audio processing examples](http://www.ee.columbia.edu/~dpwe/resources/matlab/).

# %% [markdown]
# ### 2. IPython.display.Audio
#
# [`IPython.display.Audio`](http://ipython.org/ipython-doc/stable/api/generated/IPython.display.html#IPython.display.Audio) lets you play audio directly in an IPython notebook.

# %% [markdown]
# ## Included Audio Data

# %% [markdown]
# This GitHub repository includes many short audio excerpts for your convenience.

# %% [markdown]
# Here are the files currently in the `audio` directory:

# %%
mirdotcom.list_audio()

# %% [markdown]
# Visit https://ccrma.stanford.edu/workshops/mir2014/audio/ for more audio files.

# %% [markdown]
# ## Reading Audio

# %% [markdown]
# Use [`librosa.load`](https://librosa.org/doc/latest/generated/librosa.load.html#librosa.load) to load an audio file into an audio array. Return both the audio array as well as the sample rate:

# %%
import librosa

fp = mirdotcom.get_audio("simple_loop.wav")
x, sr = librosa.load(fp)

# %% [markdown]
# If you receive an error with `librosa.load`, you may need to [install ffmpeg](https://librosa.org/doc/latest/install.html#ffmpeg).

# %% [markdown]
# Display the length of the audio array and sample rate:

# %%
print(x.shape)
print(sr)

# %% [markdown]
# ## Visualizing Audio

# %% [markdown]
# In order to display plots inside the Jupyter notebook, run the following commands, preferably at the top of your notebook:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display

# %% [markdown]
# Plot the audio array using [`librosa.display.waveshow`](https://librosa.org/doc/latest/generated/librosa.display.waveshow.html#librosa.display.waveshow):

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %% [markdown]
# Display a spectrogram using [`librosa.display.specshow`](https://librosa.org/doc/latest/generated/librosa.display.specshow.html#librosa.display.specshow):

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis="time", y_axis="hz")

# %% [markdown]
# ## Playing Audio

# %% [markdown]
# ### `IPython.display.Audio`

# %% [markdown]
# Using [`IPython.display.Audio`](http://ipython.org/ipython-doc/2/api/generated/IPython.lib.display.html#IPython.lib.display.Audio), you can play an audio file:

# %%
import IPython.display as ipd

fp = mirdotcom.get_audio("conga_groove.wav")
ipd.Audio(fp)  # load a local WAV file

# %% [markdown]
# `Audio` can also accept a NumPy array. Let's synthesize a pure tone at 440 Hz:

# %%
import numpy

sr = 22050  # sample rate
T = 2.0  # seconds
t = numpy.linspace(0, T, int(T * sr), endpoint=False)  # time variable
x = 0.5 * numpy.sin(2 * numpy.pi * 440 * t)  # pure sine wave at 440 Hz

# %% [markdown]
# Listen to the audio array:

# %%
ipd.Audio(x, rate=sr)  # load a NumPy array

# %% [markdown]
# ## Writing Audio

# %% [markdown]
# `soundfile.write` saves a NumPy array to a WAV file.

# %%
import soundfile

fp = mirdotcom.get_audio("tone_440.wav")
soundfile.write(fp, x, sr)
